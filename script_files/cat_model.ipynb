# %%
from huggingface_hub import login

# %%
login(token="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")
# Out:
# Token will not been saved to git credential helper. Pass `add_to_git_credential=True` if you want to set the git credential as well.
# Token is valid (permission: write).
# Your token has been saved to /home/myid/rk42218/.cache/huggingface/token
# Login successful

# %%
from huggingface_hub import snapshot_download

local_dir = "./cat"
snapshot_download("diffusers/cat_toy_example", local_dir=local_dir, repo_type="dataset", ignore_patterns=".gitattributes")
# Out:
# Fetching 6 files:   0%|          | 0/6 [00:00<?, ?it/s]
# 1.jpeg:   0%|          | 0.00/490k [00:00<?, ?B/s]
# 4.jpeg:   0%|          | 0.00/150k [00:00<?, ?B/s]
# 2.jpeg:   0%|          | 0.00/292k [00:00<?, ?B/s]
# 3.jpeg:   0%|          | 0.00/214k [00:00<?, ?B/s]
# 7.jpeg:   0%|          | 0.00/160k [00:00<?, ?B/s]
# 6.jpeg:   0%|          | 0.00/435k [00:00<?, ?B/s]
# '/home/myid/rk42218/cat'

# %%
export MODEL_NAME="runwayml/stable-diffusion-v1-5"
export DATA_DIR="./cat"

accelerate launch './diffusers/examples/textual_inversion/textual_inversion.py' \
  --pretrained_model_name_or_path=$MODEL_NAME \
  --train_data_dir=$DATA_DIR \
  --learnable_property="object" \
  --placeholder_token="<cat-toy>" \
  --initializer_token="toy" \
  --resolution=512 \
  --train_batch_size=1 \
  --gradient_accumulation_steps=4 \
  --max_train_steps=3000 \
  --learning_rate=5.0e-04 \
  --scale_lr \
  --lr_scheduler="constant" \
  --lr_warmup_steps=0 \
  --push_to_hub \
  --output_dir="textual_inversion_cat"
# Out:
# Traceback (most recent call last):
#   File "/home/myid/rk42218/miniconda3/envs/img2img/lib/python3.8/site-packages/diffusers/utils/import_utils.py", line 710, in _get_module
#     return importlib.import_module("." + module_name, self.__name__)
#   File "/home/myid/rk42218/miniconda3/envs/img2img/lib/python3.8/importlib/__init__.py", line 127, in import_module
# Traceback (most recent call last):
#   File "/home/myid/rk42218/miniconda3/envs/img2img/lib/python3.8/site-packages/diffusers/utils/import_utils.py", line 710, in _get_module
#     return importlib.import_module("." + module_name, self.__name__)
#   File "/home/myid/rk42218/miniconda3/envs/img2img/lib/python3.8/importlib/__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1014, in _gcd_import
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1014, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 991, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 991, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 975, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 975, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 671, in _load_unlocked
#   File "<frozen importlib._bootstrap>", line 671, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 843, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 843, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/home/myid/rk42218/miniconda3/envs/img2img/lib/python3.8/site-packages/diffusers/models/autoencoder_kl.py", line 24, in <module>
#   File "/home/myid/rk42218/miniconda3/envs/img2img/lib/python3.8/site-packages/diffusers/models/autoencoder_kl.py", line 24, in <module>
#     from .attention_processor import (
#   File "/home/myid/rk42218/miniconda3/envs/img2img/lib/python3.8/site-packages/diffusers/models/attention_processor.py", line 24, in <module>
#     from .attention_processor import (
#   File "/home/myid/rk42218/miniconda3/envs/img2img/lib/python3.8/site-packages/diffusers/models/attention_processor.py", line 24, in <module>
#     from .lora import LoRACompatibleLinear, LoRALinearLayer
#   File "/home/myid/rk42218/miniconda3/envs/img2img/lib/python3.8/site-packages/diffusers/models/lora.py", line 21, in <module>
#     from .lora import LoRACompatibleLinear, LoRALinearLayer
#   File "/home/myid/rk42218/miniconda3/envs/img2img/lib/python3.8/site-packages/diffusers/models/lora.py", line 21, in <module>
#     from ..loaders import PatchedLoraProjection, text_encoder_attn_modules, text_encoder_mlp_modules
# ImportError: cannot import name 'PatchedLoraProjection' from 'diffusers.loaders' (/home/myid/rk42218/miniconda3/envs/img2img/lib/python3.8/site-packages/diffusers/loaders/__init__.py)
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "textual_inversion.py", line 46, in <module>
#     from ..loaders import PatchedLoraProjection, text_encoder_attn_modules, text_encoder_mlp_modules
# ImportError: cannot import name 'PatchedLoraProjection' from 'diffusers.loaders' (/home/myid/rk42218/miniconda3/envs/img2img/lib/python3.8/site-packages/diffusers/loaders/__init__.py)
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "textual_inversion.py", line 46, in <module>
#     from diffusers import (
#   File "<frozen importlib._bootstrap>", line 1039, in _handle_fromlist
#   File "/home/myid/rk42218/miniconda3/envs/img2img/lib/python3.8/site-packages/diffusers/utils/import_utils.py", line 701, in __getattr__
#     from diffusers import (
#   File "<frozen importlib._bootstrap>", line 1039, in _handle_fromlist
#   File "/home/myid/rk42218/miniconda3/envs/img2img/lib/python3.8/site-packages/diffusers/utils/import_utils.py", line 701, in __getattr__
#     value = getattr(module, name)
#   File "/home/myid/rk42218/miniconda3/envs/img2img/lib/python3.8/site-packages/diffusers/utils/import_utils.py", line 700, in __getattr__
#     value = getattr(module, name)
#   File "/home/myid/rk42218/miniconda3/envs/img2img/lib/python3.8/site-packages/diffusers/utils/import_utils.py", line 700, in __getattr__
#     module = self._get_module(self._class_to_module[name])
#   File "/home/myid/rk42218/miniconda3/envs/img2img/lib/python3.8/site-packages/diffusers/utils/import_utils.py", line 712, in _get_module
#     module = self._get_module(self._class_to_module[name])
#   File "/home/myid/rk42218/miniconda3/envs/img2img/lib/python3.8/site-packages/diffusers/utils/import_utils.py", line 712, in _get_module
#     raise RuntimeError(
# RuntimeError: Failed to import diffusers.models.autoencoder_kl because of the following error (look up to see its traceback):
# cannot import name 'PatchedLoraProjection' from 'diffusers.loaders' (/home/myid/rk42218/miniconda3/envs/img2img/lib/python3.8/site-packages/diffusers/loaders/__init__.py)
#     raise RuntimeError(
# RuntimeError: Failed to import diffusers.models.autoencoder_kl because of the following error (look up to see its traceback):
# cannot import name 'PatchedLoraProjection' from 'diffusers.loaders' (/home/myid/rk42218/miniconda3/envs/img2img/lib/python3.8/site-packages/diffusers/loaders/__init__.py)
# Traceback (most recent call last):
#   File "/home/myid/rk42218/miniconda3/envs/img2img/lib/python3.8/site-packages/diffusers/utils/import_utils.py", line 710, in _get_module
#     return importlib.import_module("." + module_name, self.__name__)
#   File "/home/myid/rk42218/miniconda3/envs/img2img/lib/python3.8/importlib/__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1014, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 991, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 975, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 671, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 843, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/home/myid/rk42218/miniconda3/envs/img2img/lib/python3.8/site-packages/diffusers/models/autoencoder_kl.py", line 24, in <module>
#     from .attention_processor import (
#   File "/home/myid/rk42218/miniconda3/envs/img2img/lib/python3.8/site-packages/diffusers/models/attention_processor.py", line 24, in <module>
#     from .lora import LoRACompatibleLinear, LoRALinearLayer
#   File "/home/myid/rk42218/miniconda3/envs/img2img/lib/python3.8/site-packages/diffusers/models/lora.py", line 21, in <module>
#     from ..loaders import PatchedLoraProjection, text_encoder_attn_modules, text_encoder_mlp_modules
# ImportError: cannot import name 'PatchedLoraProjection' from 'diffusers.loaders' (/home/myid/rk42218/miniconda3/envs/img2img/lib/python3.8/site-packages/diffusers/loaders/__init__.py)
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "textual_inversion.py", line 46, in <module>
#     from diffusers import (
#   File "<frozen importlib._bootstrap>", line 1039, in _handle_fromlist
#   File "/home/myid/rk42218/miniconda3/envs/img2img/lib/python3.8/site-packages/diffusers/utils/import_utils.py", line 701, in __getattr__
#     value = getattr(module, name)
#   File "/home/myid/rk42218/miniconda3/envs/img2img/lib/python3.8/site-packages/diffusers/utils/import_utils.py", line 700, in __getattr__
#     module = self._get_module(self._class_to_module[name])
#   File "/home/myid/rk42218/miniconda3/envs/img2img/lib/python3.8/site-packages/diffusers/utils/import_utils.py", line 712, in _get_module
#     raise RuntimeError(
# RuntimeError: Failed to import diffusers.models.autoencoder_kl because of the following error (look up to see its traceback):
# cannot import name 'PatchedLoraProjection' from 'diffusers.loaders' (/home/myid/rk42218/miniconda3/envs/img2img/lib/python3.8/site-packages/diffusers/loaders/__init__.py)
# Traceback (most recent call last):
#   File "/home/myid/rk42218/miniconda3/envs/img2img/lib/python3.8/site-packages/diffusers/utils/import_utils.py", line 710, in _get_module
#     return importlib.import_module("." + module_name, self.__name__)
#   File "/home/myid/rk42218/miniconda3/envs/img2img/lib/python3.8/importlib/__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1014, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 991, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 975, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 671, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 843, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/home/myid/rk42218/miniconda3/envs/img2img/lib/python3.8/site-packages/diffusers/models/autoencoder_kl.py", line 24, in <module>
#     from .attention_processor import (
#   File "/home/myid/rk42218/miniconda3/envs/img2img/lib/python3.8/site-packages/diffusers/models/attention_processor.py", line 24, in <module>
#     from .lora import LoRACompatibleLinear, LoRALinearLayer
#   File "/home/myid/rk42218/miniconda3/envs/img2img/lib/python3.8/site-packages/diffusers/models/lora.py", line 21, in <module>
#     from ..loaders import PatchedLoraProjection, text_encoder_attn_modules, text_encoder_mlp_modules
# ImportError: cannot import name 'PatchedLoraProjection' from 'diffusers.loaders' (/home/myid/rk42218/miniconda3/envs/img2img/lib/python3.8/site-packages/diffusers/loaders/__init__.py)
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "textual_inversion.py", line 46, in <module>
#     from diffusers import (
#   File "<frozen importlib._bootstrap>", line 1039, in _handle_fromlist
#   File "/home/myid/rk42218/miniconda3/envs/img2img/lib/python3.8/site-packages/diffusers/utils/import_utils.py", line 701, in __getattr__
#     value = getattr(module, name)
#   File "/home/myid/rk42218/miniconda3/envs/img2img/lib/python3.8/site-packages/diffusers/utils/import_utils.py", line 700, in __getattr__
#     module = self._get_module(self._class_to_module[name])
#   File "/home/myid/rk42218/miniconda3/envs/img2img/lib/python3.8/site-packages/diffusers/utils/import_utils.py", line 712, in _get_module
#     raise RuntimeError(
# RuntimeError: Failed to import diffusers.models.autoencoder_kl because of the following error (look up to see its traceback):
# cannot import name 'PatchedLoraProjection' from 'diffusers.loaders' (/home/myid/rk42218/miniconda3/envs/img2img/lib/python3.8/site-packages/diffusers/loaders/__init__.py)
# [2023-11-22 14:36:57,858] torch.distributed.elastic.multiprocessing.api: [ERROR] failed (exitcode: 1) local_rank: 0 (pid: 567831) of binary: /home/myid/rk42218/miniconda3/envs/img2img/bin/python
# Traceback (most recent call last):
#   File "/home/myid/rk42218/miniconda3/envs/img2img/bin/accelerate", line 8, in <module>
#     sys.exit(main())
#   File "/home/myid/rk42218/miniconda3/envs/img2img/lib/python3.8/site-packages/accelerate/commands/accelerate_cli.py", line 47, in main
#     args.func(args)
#   File "/home/myid/rk42218/miniconda3/envs/img2img/lib/python3.8/site-packages/accelerate/commands/launch.py", line 985, in launch_command
#     multi_gpu_launcher(args)
#   File "/home/myid/rk42218/miniconda3/envs/img2img/lib/python3.8/site-packages/accelerate/commands/launch.py", line 654, in multi_gpu_launcher
#     distrib_run.run(args)
#   File "/home/myid/rk42218/miniconda3/envs/img2img/lib/python3.8/site-packages/torch/distributed/run.py", line 797, in run
#     elastic_launch(
#   File "/home/myid/rk42218/miniconda3/envs/img2img/lib/python3.8/site-packages/torch/distributed/launcher/api.py", line 134, in __call__
#     return launch_agent(self._config, self._entrypoint, list(args))
#   File "/home/myid/rk42218/miniconda3/envs/img2img/lib/python3.8/site-packages/torch/distributed/launcher/api.py", line 264, in launch_agent
#     raise ChildFailedError(
# torch.distributed.elastic.multiprocessing.errors.ChildFailedError:
# ============================================================
# textual_inversion.py FAILED
# ------------------------------------------------------------
# Failures:
# [1]:
#   time      : 2023-11-22_14:36:57
#   host      : csci-cscuda
#   rank      : 1 (local_rank: 1)
#   exitcode  : 1 (pid: 567832)
#   error_file: <N/A>
#   traceback : To enable traceback see: https://pytorch.org/docs/stable/elastic/errors.html
# [2]:
#   time      : 2023-11-22_14:36:57
#   host      : csci-cscuda
#   rank      : 2 (local_rank: 2)
#   exitcode  : 1 (pid: 567833)
#   error_file: <N/A>
#   traceback : To enable traceback see: https://pytorch.org/docs/stable/elastic/errors.html
# [3]:
#   time      : 2023-11-22_14:36:57
#   host      : csci-cscuda
#   rank      : 3 (local_rank: 3)
#   exitcode  : 1 (pid: 567834)
#   error_file: <N/A>
#   traceback : To enable traceback see: https://pytorch.org/docs/stable/elastic/errors.html
# ------------------------------------------------------------
# Root Cause (first observed failure):
# [0]:
#   time      : 2023-11-22_14:36:57
#   host      : csci-cscuda
#   rank      : 0 (local_rank: 0)
#   exitcode  : 1 (pid: 567831)
#   error_file: <N/A>
#   traceback : To enable traceback see: https://pytorch.org/docs/stable/elastic/errors.html
# ============================================================

# %%
python main.py --base configs/latent-diffusion/txt2img-1p4B-finetune.yaml 
               -t 
               --actual_resume /models/ldm/stable-diffusion-v1/model.ckpt 
               -n <run_name> 
               --gpus 0, 
               --data_root /path/to/directory/with/images
               --init_word <initialization_word>
# Out:
#   Cell In[8], line 1
#     python main.py --base configs/latent-diffusion/txt2img-1p4B-finetune.yaml
#            ^
# SyntaxError: invalid syntax

# %%
# make sure you're logged in with `huggingface-cli login`
from torch import autocast
from diffusers import StableDiffusionPipeline

pipe = StableDiffusionPipeline.from_pretrained(
	"CompVis/stable-diffusion-v1-4", 
	use_auth_token=True
).to("cuda")

prompt = "a photo of an astronaut riding a horse on mars"
with autocast("cuda"):
    image = pipe(prompt)["sample"][0]  
    
image.save("astronaut_rides_horse.png")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File ~/miniconda3/envs/img2img/lib/python3.8/site-packages/diffusers/utils/import_utils.py:710, in _LazyModule._get_module(self, module_name)
#     709 try:
# --> 710     return importlib.import_module("." + module_name, self.__name__)
#     711 except Exception as e:
#
# File ~/miniconda3/envs/img2img/lib/python3.8/importlib/__init__.py:127, in import_module(name, package)
#     126         level += 1
# --> 127 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1014, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:991, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:975, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:671, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:843, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:219, in _call_with_frames_removed(f, *args, **kwds)
#
# File ~/miniconda3/envs/img2img/lib/python3.8/site-packages/diffusers/loaders/lora.py:27
#      26 from ..models.modeling_utils import _LOW_CPU_MEM_USAGE_DEFAULT, load_model_dict_into_meta
# ---> 27 from ..utils import (
#      28     DIFFUSERS_CACHE,
#      29     HF_HUB_OFFLINE,
#      30     USE_PEFT_BACKEND,
#      31     _get_model_file,
#      32     convert_state_dict_to_diffusers,
#      33     convert_state_dict_to_peft,
#      34     convert_unet_state_dict_to_peft,
#      35     delete_adapter_layers,
#      36     deprecate,
#      37     get_adapter_name,
#      38     get_peft_kwargs,
#      39     is_accelerate_available,
#      40     is_transformers_available,
#      41     logging,
#      42     recurse_remove_peft_layers,
#      43     scale_lora_layers,
#      44     set_adapter_layers,
#      45     set_weights_and_activate_adapters,
#      46 )
#      49 if is_transformers_available():
#
# ImportError: cannot import name 'delete_adapter_layers' from 'diffusers.utils' (/home/myid/rk42218/miniconda3/envs/img2img/lib/python3.8/site-packages/diffusers/utils/__init__.py)
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# File ~/miniconda3/envs/img2img/lib/python3.8/site-packages/diffusers/utils/import_utils.py:710, in _LazyModule._get_module(self, module_name)
#     709 try:
# --> 710     return importlib.import_module("." + module_name, self.__name__)
#     711 except Exception as e:
#
# File ~/miniconda3/envs/img2img/lib/python3.8/importlib/__init__.py:127, in import_module(name, package)
#     126         level += 1
# --> 127 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1014, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:991, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:975, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:671, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:843, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:219, in _call_with_frames_removed(f, *args, **kwds)
#
# File ~/miniconda3/envs/img2img/lib/python3.8/site-packages/diffusers/pipelines/stable_diffusion/pipeline_stable_diffusion.py:24
#      23 from ...image_processor import VaeImageProcessor
# ---> 24 from ...loaders import FromSingleFileMixin, LoraLoaderMixin, TextualInversionLoaderMixin
#      25 from ...models import AutoencoderKL, UNet2DConditionModel
#
# File <frozen importlib._bootstrap>:1039, in _handle_fromlist(module, fromlist, import_, recursive)
#
# File ~/miniconda3/envs/img2img/lib/python3.8/site-packages/diffusers/utils/import_utils.py:700, in _LazyModule.__getattr__(self, name)
#     699 elif name in self._class_to_module.keys():
# --> 700     module = self._get_module(self._class_to_module[name])
#     701     value = getattr(module, name)
#
# File ~/miniconda3/envs/img2img/lib/python3.8/site-packages/diffusers/utils/import_utils.py:712, in _LazyModule._get_module(self, module_name)
#     711 except Exception as e:
# --> 712     raise RuntimeError(
#     713         f"Failed to import {self.__name__}.{module_name} because of the following error (look up to see its"
#     714         f" traceback):\n{e}"
#     715     ) from e
#
# RuntimeError: Failed to import diffusers.loaders.lora because of the following error (look up to see its traceback):
# cannot import name 'delete_adapter_layers' from 'diffusers.utils' (/home/myid/rk42218/miniconda3/envs/img2img/lib/python3.8/site-packages/diffusers/utils/__init__.py)
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# /home/myid/rk42218/cat_model.ipynb Cell 10 line 3
#       <a href='vscode-notebook-cell://ssh-remote%2Bcscuda.cs.uga.edu/home/myid/rk42218/cat_model.ipynb#X12sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> # make sure you're logged in with `huggingface-cli login`
#       <a href='vscode-notebook-cell://ssh-remote%2Bcscuda.cs.uga.edu/home/myid/rk42218/cat_model.ipynb#X12sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> from torch import autocast
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bcscuda.cs.uga.edu/home/myid/rk42218/cat_model.ipynb#X12sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> from diffusers import StableDiffusionPipeline
#       <a href='vscode-notebook-cell://ssh-remote%2Bcscuda.cs.uga.edu/home/myid/rk42218/cat_model.ipynb#X12sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a> pipe = StableDiffusionPipeline.from_pretrained(
#       <a href='vscode-notebook-cell://ssh-remote%2Bcscuda.cs.uga.edu/home/myid/rk42218/cat_model.ipynb#X12sdnNjb2RlLXJlbW90ZQ%3D%3D?line=5'>6</a> 	"CompVis/stable-diffusion-v1-4",
#       <a href='vscode-notebook-cell://ssh-remote%2Bcscuda.cs.uga.edu/home/myid/rk42218/cat_model.ipynb#X12sdnNjb2RlLXJlbW90ZQ%3D%3D?line=6'>7</a> 	use_auth_token=True
#       <a href='vscode-notebook-cell://ssh-remote%2Bcscuda.cs.uga.edu/home/myid/rk42218/cat_model.ipynb#X12sdnNjb2RlLXJlbW90ZQ%3D%3D?line=7'>8</a> ).to("cuda")
#      <a href='vscode-notebook-cell://ssh-remote%2Bcscuda.cs.uga.edu/home/myid/rk42218/cat_model.ipynb#X12sdnNjb2RlLXJlbW90ZQ%3D%3D?line=9'>10</a> prompt = "a photo of an astronaut riding a horse on mars"
#
# File <frozen importlib._bootstrap>:1039, in _handle_fromlist(module, fromlist, import_, recursive)
#
# File ~/miniconda3/envs/img2img/lib/python3.8/site-packages/diffusers/utils/import_utils.py:701, in _LazyModule.__getattr__(self, name)
#     699 elif name in self._class_to_module.keys():
#     700     module = self._get_module(self._class_to_module[name])
# --> 701     value = getattr(module, name)
#     702 else:
#     703     raise AttributeError(f"module {self.__name__} has no attribute {name}")
#
# File ~/miniconda3/envs/img2img/lib/python3.8/site-packages/diffusers/utils/import_utils.py:701, in _LazyModule.__getattr__(self, name)
#     699 elif name in self._class_to_module.keys():
#     700     module = self._get_module(self._class_to_module[name])
# --> 701     value = getattr(module, name)
#     702 else:
#     703     raise AttributeError(f"module {self.__name__} has no attribute {name}")
#
# File ~/miniconda3/envs/img2img/lib/python3.8/site-packages/diffusers/utils/import_utils.py:700, in _LazyModule.__getattr__(self, name)
#     698     value = self._get_module(name)
#     699 elif name in self._class_to_module.keys():
# --> 700     module = self._get_module(self._class_to_module[name])
#     701     value = getattr(module, name)
#     702 else:
#
# File ~/miniconda3/envs/img2img/lib/python3.8/site-packages/diffusers/utils/import_utils.py:712, in _LazyModule._get_module(self, module_name)
#     710     return importlib.import_module("." + module_name, self.__name__)
#     711 except Exception as e:
# --> 712     raise RuntimeError(
#     713         f"Failed to import {self.__name__}.{module_name} because of the following error (look up to see its"
#     714         f" traceback):\n{e}"
#     715     ) from e
#
# RuntimeError: Failed to import diffusers.pipelines.stable_diffusion.pipeline_stable_diffusion because of the following error (look up to see its traceback):
# Failed to import diffusers.loaders.lora because of the following error (look up to see its traceback):
# cannot import name 'delete_adapter_layers' from 'diffusers.utils' (/home/myid/rk42218/miniconda3/envs/img2img/lib/python3.8/site-packages/diffusers/utils/__init__.py)
